# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torchvision
from torchvision import transforms, datasets, models
from d2l import torch as d2l
import os
import cv2
import time
import random
from model.residual_attention_network import ResidualAttentionModel_92_32input_update as ResidualAttentionModel
from model.residual_attention_network import ResidualModel_92_32input_update as ResNet

def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

seed_everything(42)

# %%
# 数据增强
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop((32, 32), padding=4), 
    transforms.ToTensor()
])
test_transform = transforms.Compose([
    transforms.ToTensor()
])
# 加载CIFAR-10 Dataset
train_dataset = datasets.CIFAR10(root='./data/',
                               train=True,
                               transform=transform,
                               download=False)

test_dataset = datasets.CIFAR10(root='./data/',
                              train=False,
                              transform=test_transform)

# Data Loader (Input Pipeline)
train_iter = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=64, # 64
                                           shuffle=True, num_workers=8)
test_iter = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=20,
                                          shuffle=False)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = ResNet() # 初始化模型
model.to(device)
print(model) # 打印模型结构
# Out:
# ResidualModel_92_32input_update(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (residual_block1): ResidualBlock(
#     (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (conv4): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (residual_block2): ResidualBlock(
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (conv4): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   )
#   (residual_block3): ResidualBlock(
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (conv4): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   )
#   (residual_block4): ResidualBlock(
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (conv4): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (residual_block5): ResidualBlock(
#     (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (conv4): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (residual_block6): ResidualBlock(
#     (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (conv4): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (mpool2): Sequential(
#     (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): ReLU(inplace=True)
#     (2): AvgPool2d(kernel_size=8, stride=8, padding=0)
#   )
#   (fc): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
# 记录后期可视化数据
vis_data = {
    'class_name': ['plane', 'car', 'bird', 'cat',
                   'deer', 'dog', 'frog', 'horse', 'ship', 'truck'],
    'eval_acc': [],
    'eval_class_acc': [],
    'eval_loss': [],
    'train_loss': []
}

# %%
def test(model, test_loader, criterion, btrain=False, model_file='./best_model_resnet.pth'):
    # Test
    if not btrain:
        model.load_state_dict(torch.load(model_file))
    model.eval()

    correct = 0
    total = 0
    #
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))

    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.data).sum()
        #
        c = (predicted == labels.data).squeeze()
        labels = labels.detach().cpu().numpy()
        for i in range(labels.shape[0]):
            label = labels[i]
            class_correct[label] += c[i]
            class_total[label] += 1

    print('Accuracy of the model on the test images:', float(correct)/total)
    tmp_acc = []
    for i in range(10):
        print(
            f'Accuracy of {classes[i] :.5s} : {class_correct[i] / class_total[i] : .4f}')
        tmp_acc.append((class_correct[i] / class_total[i]).detach().cpu().numpy().tolist())

    if btrain:
        vis_data['eval_loss'] += [float(loss.detach().cpu().numpy())]
        vis_data['eval_acc'] += [float(correct)/total]
        vis_data['eval_class_acc'].append(tmp_acc)

    return correct / total

# %%
lr = 0.1
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=0.9, nesterov=True, weight_decay=0.0001)
is_train = True
acc_best = 0
total_epoch = 100

if is_train:
    # Training
    for epoch in range(total_epoch):
        model.train()
        tims = time.time()
        for i, (images, labels) in enumerate(train_iter):
            images = images.to(device)
            # print(images.data)
            labels = labels.to(device)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

        print("Epoch [%d/%d], Loss: %.4f" %
              (epoch+1, total_epoch, loss.item()))
        print('the epoch takes time:', time.time()-tims)
        vis_data['train_loss'] += [loss.item()]

        print('evaluate test set:')
        acc = test(model, test_iter, criterion, btrain=True)
        if acc > acc_best:
            acc_best = acc
            print('current best acc,', acc_best)
            torch.save(model.state_dict(), './best_model_resnet.pth')

        # Decaying Learning Rate
        if (epoch+1) / float(total_epoch) == 0.3 or (epoch+1) / float(total_epoch) == 0.6 or (epoch+1) / float(total_epoch) == 0.9:
            lr /= 10
            print('reset learning rate to:', lr)
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
                print(param_group['lr'])
    # Save the Model
    torch.save(model.state_dict(), 'last_model_resnet.pth')

else:
    test(model, test_iter, criterion, btrain=False)
# Out:
# Epoch [1/100], Loss: 1.0811
# the epoch takes time: 61.3788366317749
# evaluate test set:
# Accuracy of the model on the test images: 0.3841
# Accuracy of plane :  0.4540
# Accuracy of car :  0.5100
# Accuracy of bird :  0.4550
# Accuracy of cat :  0.0820
# Accuracy of deer :  0.1560
# Accuracy of dog :  0.1470
# Accuracy of frog :  0.8480
# Accuracy of horse :  0.2000
# Accuracy of ship :  0.8510
# Accuracy of truck :  0.1380
# current best acc, tensor(0.3841, device='cuda:0')
# Epoch [2/100], Loss: 1.0092
# the epoch takes time: 55.825268030166626
# evaluate test set:
# Accuracy of the model on the test images: 0.4381
# Accuracy of plane :  0.2320
# Accuracy of car :  0.7170
# Accuracy of bird :  0.7780
# Accuracy of cat :  0.3840
# Accuracy of deer :  0.1040
# Accuracy of dog :  0.2760
# Accuracy of frog :  0.3830
# Accuracy of horse :  0.2370
# Accuracy of ship :  0.8690
# Accuracy of truck :  0.4010
# current best acc, tensor(0.4381, device='cuda:0')
# Epoch [3/100], Loss: 1.3854
# the epoch takes time: 54.93459749221802
# evaluate test set:
# Accuracy of the model on the test images: 0.6646
# Accuracy of plane :  0.4860
# Accuracy of car :  0.7550
# Accuracy of bird :  0.2330
# Accuracy of cat :  0.4820
# Accuracy of deer :  0.7190
# Accuracy of dog :  0.6740
# Accuracy of frog :  0.7760
# Accuracy of horse :  0.7420
# Accuracy of ship :  0.9240
# Accuracy of truck :  0.8550
# current best acc, tensor(0.6646, device='cuda:0')
# Epoch [4/100], Loss: 0.5055
# the epoch takes time: 55.503127336502075
# evaluate test set:
# Accuracy of the model on the test images: 0.6896
# Accuracy of plane :  0.6560
# Accuracy of car :  0.9160
# Accuracy of bird :  0.7220
# Accuracy of cat :  0.4490
# Accuracy of deer :  0.5060
# Accuracy of dog :  0.7390
# Accuracy of frog :  0.7560
# Accuracy of horse :  0.3930
# Accuracy of ship :  0.9170
# Accuracy of truck :  0.8420
# current best acc, tensor(0.6896, device='cuda:0')
# Epoch [5/100], Loss: 0.4498
# the epoch takes time: 55.30680990219116
# evaluate test set:
# Accuracy of the model on the test images: 0.6312
# Accuracy of plane :  0.6500
# Accuracy of car :  0.9630
# Accuracy of bird :  0.7270
# Accuracy of cat :  0.4990
# Accuracy of deer :  0.3890
# Accuracy of dog :  0.5760
# Accuracy of frog :  0.7920
# Accuracy of horse :  0.1980
# Accuracy of ship :  0.7310
# Accuracy of truck :  0.7870
# Epoch [6/100], Loss: 1.2601
# the epoch takes time: 55.838906049728394
# evaluate test set:
# Accuracy of the model on the test images: 0.7575
# Accuracy of plane :  0.8510
# Accuracy of car :  0.8510
# Accuracy of bird :  0.6960
# Accuracy of cat :  0.4970
# Accuracy of deer :  0.6420
# Accuracy of dog :  0.5490
# Accuracy of frog :  0.8370
# Accuracy of horse :  0.8660
# Accuracy of ship :  0.9040
# Accuracy of truck :  0.8820
# current best acc, tensor(0.7575, device='cuda:0')
# Epoch [7/100], Loss: 0.9560
# the epoch takes time: 55.511903524398804
# evaluate test set:
# Accuracy of the model on the test images: 0.7723
# Accuracy of plane :  0.7310
# Accuracy of car :  0.9250
# Accuracy of bird :  0.6690
# Accuracy of cat :  0.4260
# Accuracy of deer :  0.7660
# Accuracy of dog :  0.6930
# Accuracy of frog :  0.8790
# Accuracy of horse :  0.8220
# Accuracy of ship :  0.9330
# Accuracy of truck :  0.8790
# current best acc, tensor(0.7723, device='cuda:0')
# Epoch [8/100], Loss: 0.3920
# the epoch takes time: 55.282448053359985
# evaluate test set:
# Accuracy of the model on the test images: 0.7837
# Accuracy of plane :  0.7310
# Accuracy of car :  0.8940
# Accuracy of bird :  0.7500
# Accuracy of cat :  0.7380
# Accuracy of deer :  0.7920
# Accuracy of dog :  0.6470
# Accuracy of frog :  0.8020
# Accuracy of horse :  0.6940
# Accuracy of ship :  0.9630
# Accuracy of truck :  0.8260
# current best acc, tensor(0.7837, device='cuda:0')
# Epoch [9/100], Loss: 0.6056
# the epoch takes time: 53.70192909240723
# evaluate test set:
# Accuracy of the model on the test images: 0.7714
# Accuracy of plane :  0.8220
# Accuracy of car :  0.9390
# Accuracy of bird :  0.5360
# Accuracy of cat :  0.7340
# Accuracy of deer :  0.8540
# Accuracy of dog :  0.5970
# Accuracy of frog :  0.8850
# Accuracy of horse :  0.6150
# Accuracy of ship :  0.9330
# Accuracy of truck :  0.7990
# Epoch [10/100], Loss: 0.5532
# the epoch takes time: 54.8642361164093
# evaluate test set:
# Accuracy of the model on the test images: 0.7932
# Accuracy of plane :  0.8810
# Accuracy of car :  0.8980
# Accuracy of bird :  0.5280
# Accuracy of cat :  0.5940
# Accuracy of deer :  0.8040
# Accuracy of dog :  0.7680
# Accuracy of frog :  0.8820
# Accuracy of horse :  0.7500
# Accuracy of ship :  0.8830
# Accuracy of truck :  0.9440
# current best acc, tensor(0.7932, device='cuda:0')
# Epoch [11/100], Loss: 0.5768
# the epoch takes time: 54.832406520843506
# evaluate test set:
# Accuracy of the model on the test images: 0.8117
# Accuracy of plane :  0.7740
# Accuracy of car :  0.9020
# Accuracy of bird :  0.8260
# Accuracy of cat :  0.6950
# Accuracy of deer :  0.8200
# Accuracy of dog :  0.7190
# Accuracy of frog :  0.8110
# Accuracy of horse :  0.7460
# Accuracy of ship :  0.8680
# Accuracy of truck :  0.9560
# current best acc, tensor(0.8117, device='cuda:0')
# Epoch [12/100], Loss: 0.7010
# the epoch takes time: 54.839272022247314
# evaluate test set:
# Accuracy of the model on the test images: 0.75
# Accuracy of plane :  0.6510
# Accuracy of car :  0.8010
# Accuracy of bird :  0.9220
# Accuracy of cat :  0.3380
# Accuracy of deer :  0.7120
# Accuracy of dog :  0.5820
# Accuracy of frog :  0.7510
# Accuracy of horse :  0.8330
# Accuracy of ship :  0.9440
# Accuracy of truck :  0.9660
# Epoch [13/100], Loss: 0.3551
# the epoch takes time: 55.108078956604004
# evaluate test set:
# Accuracy of the model on the test images: 0.7497
# Accuracy of plane :  0.8960
# Accuracy of car :  0.9420
# Accuracy of bird :  0.6700
# Accuracy of cat :  0.8630
# Accuracy of deer :  0.6870
# Accuracy of dog :  0.4860
# Accuracy of frog :  0.4630
# Accuracy of horse :  0.7310
# Accuracy of ship :  0.9060
# Accuracy of truck :  0.8530
# Epoch [14/100], Loss: 0.5374
# the epoch takes time: 54.92807078361511
# evaluate test set:
# Accuracy of the model on the test images: 0.8414
# Accuracy of plane :  0.8790
# Accuracy of car :  0.9550
# Accuracy of bird :  0.6860
# Accuracy of cat :  0.7510
# Accuracy of deer :  0.8090
# Accuracy of dog :  0.7740
# Accuracy of frog :  0.8700
# Accuracy of horse :  0.8910
# Accuracy of ship :  0.9300
# Accuracy of truck :  0.8690
# current best acc, tensor(0.8414, device='cuda:0')
# Epoch [15/100], Loss: 0.5349
# the epoch takes time: 54.4624228477478
# evaluate test set:
# Accuracy of the model on the test images: 0.8163
# Accuracy of plane :  0.8880
# Accuracy of car :  0.9510
# Accuracy of bird :  0.7600
# Accuracy of cat :  0.4810
# Accuracy of deer :  0.7100
# Accuracy of dog :  0.8680
# Accuracy of frog :  0.8800
# Accuracy of horse :  0.8470
# Accuracy of ship :  0.9400
# Accuracy of truck :  0.8380
# Epoch [16/100], Loss: 0.4753
# the epoch takes time: 54.95804572105408
# evaluate test set:
# Accuracy of the model on the test images: 0.7919
# Accuracy of plane :  0.8250
# Accuracy of car :  0.9780
# Accuracy of bird :  0.6820
# Accuracy of cat :  0.6700
# Accuracy of deer :  0.8430
# Accuracy of dog :  0.8190
# Accuracy of frog :  0.7000
# Accuracy of horse :  0.7080
# Accuracy of ship :  0.8630
# Accuracy of truck :  0.8310
# Epoch [17/100], Loss: 0.6260
# the epoch takes time: 55.13354468345642
# evaluate test set:
# Accuracy of the model on the test images: 0.824
# Accuracy of plane :  0.8220
# Accuracy of car :  0.9650
# Accuracy of bird :  0.7510
# Accuracy of cat :  0.5450
# Accuracy of deer :  0.7290
# Accuracy of dog :  0.8400
# Accuracy of frog :  0.9340
# Accuracy of horse :  0.9160
# Accuracy of ship :  0.8280
# Accuracy of truck :  0.9100
# Epoch [18/100], Loss: 0.5606
# the epoch takes time: 55.67198896408081
# evaluate test set:
# Accuracy of the model on the test images: 0.8352
# Accuracy of plane :  0.8080
# Accuracy of car :  0.9300
# Accuracy of bird :  0.8440
# Accuracy of cat :  0.6630
# Accuracy of deer :  0.8490
# Accuracy of dog :  0.6100
# Accuracy of frog :  0.9000
# Accuracy of horse :  0.8650
# Accuracy of ship :  0.9430
# Accuracy of truck :  0.9400
# Epoch [19/100], Loss: 0.9500
# the epoch takes time: 55.66686654090881
# evaluate test set:
# Accuracy of the model on the test images: 0.7815
# Accuracy of plane :  0.9620
# Accuracy of car :  0.9580
# Accuracy of bird :  0.5710
# Accuracy of cat :  0.5050
# Accuracy of deer :  0.8590
# Accuracy of dog :  0.5060
# Accuracy of frog :  0.9030
# Accuracy of horse :  0.8760
# Accuracy of ship :  0.8700
# Accuracy of truck :  0.8050
# Epoch [20/100], Loss: 0.2707
# the epoch takes time: 55.384854793548584
# evaluate test set:
# Accuracy of the model on the test images: 0.8097
# Accuracy of plane :  0.9210
# Accuracy of car :  0.9010
# Accuracy of bird :  0.7930
# Accuracy of cat :  0.4650
# Accuracy of deer :  0.6640
# Accuracy of dog :  0.8850
# Accuracy of frog :  0.7700
# Accuracy of horse :  0.9460
# Accuracy of ship :  0.8350
# Accuracy of truck :  0.9170
# Epoch [21/100], Loss: 0.4355
# the epoch takes time: 56.299577713012695
# evaluate test set:
# Accuracy of the model on the test images: 0.8017
# Accuracy of plane :  0.7770
# Accuracy of car :  0.9860
# Accuracy of bird :  0.7330
# Accuracy of cat :  0.8620
# Accuracy of deer :  0.7100
# Accuracy of dog :  0.5780
# Accuracy of frog :  0.9080
# Accuracy of horse :  0.7280
# Accuracy of ship :  0.9460
# Accuracy of truck :  0.7890
# Epoch [22/100], Loss: 0.6005
# the epoch takes time: 55.21407961845398
# evaluate test set:
# Accuracy of the model on the test images: 0.8308
# Accuracy of plane :  0.9280
# Accuracy of car :  0.9710
# Accuracy of bird :  0.8160
# Accuracy of cat :  0.7360
# Accuracy of deer :  0.7140
# Accuracy of dog :  0.7150
# Accuracy of frog :  0.8890
# Accuracy of horse :  0.8750
# Accuracy of ship :  0.9180
# Accuracy of truck :  0.7460
# Epoch [23/100], Loss: 0.2173
# the epoch takes time: 55.69831705093384
# evaluate test set:
# Accuracy of the model on the test images: 0.8566
# Accuracy of plane :  0.8100
# Accuracy of car :  0.9500
# Accuracy of bird :  0.8070
# Accuracy of cat :  0.6890
# Accuracy of deer :  0.8590
# Accuracy of dog :  0.7420
# Accuracy of frog :  0.8940
# Accuracy of horse :  0.9160
# Accuracy of ship :  0.9490
# Accuracy of truck :  0.9500
# current best acc, tensor(0.8566, device='cuda:0')
# Epoch [24/100], Loss: 0.7334
# the epoch takes time: 55.89501452445984
# evaluate test set:
# Accuracy of the model on the test images: 0.792
# Accuracy of plane :  0.7820
# Accuracy of car :  0.8880
# Accuracy of bird :  0.7260
# Accuracy of cat :  0.2190
# Accuracy of deer :  0.8770
# Accuracy of dog :  0.8940
# Accuracy of frog :  0.8490
# Accuracy of horse :  0.9490
# Accuracy of ship :  0.9790
# Accuracy of truck :  0.7570
# Epoch [25/100], Loss: 0.2846
# the epoch takes time: 55.47477388381958
# evaluate test set:
# Accuracy of the model on the test images: 0.8267
# Accuracy of plane :  0.7330
# Accuracy of car :  0.8990
# Accuracy of bird :  0.7230
# Accuracy of cat :  0.6070
# Accuracy of deer :  0.9090
# Accuracy of dog :  0.8620
# Accuracy of frog :  0.8930
# Accuracy of horse :  0.7930
# Accuracy of ship :  0.8910
# Accuracy of truck :  0.9570
# Epoch [26/100], Loss: 0.3559
# the epoch takes time: 55.76936721801758
# evaluate test set:
# Accuracy of the model on the test images: 0.841
# Accuracy of plane :  0.8380
# Accuracy of car :  0.9340
# Accuracy of bird :  0.8330
# Accuracy of cat :  0.5890
# Accuracy of deer :  0.8460
# Accuracy of dog :  0.8120
# Accuracy of frog :  0.9040
# Accuracy of horse :  0.8230
# Accuracy of ship :  0.8740
# Accuracy of truck :  0.9570
# Epoch [27/100], Loss: 0.1906
# the epoch takes time: 55.980064153671265
# evaluate test set:
# Accuracy of the model on the test images: 0.806
# Accuracy of plane :  0.8230
# Accuracy of car :  0.9160
# Accuracy of bird :  0.7690
# Accuracy of cat :  0.5560
# Accuracy of deer :  0.8150
# Accuracy of dog :  0.9470
# Accuracy of frog :  0.8250
# Accuracy of horse :  0.8070
# Accuracy of ship :  0.8830
# Accuracy of truck :  0.7190
# Epoch [28/100], Loss: 0.5319
# the epoch takes time: 55.374077558517456
# evaluate test set:
# Accuracy of the model on the test images: 0.8017
# Accuracy of plane :  0.9070
# Accuracy of car :  0.9740
# Accuracy of bird :  0.6330
# Accuracy of cat :  0.6330
# Accuracy of deer :  0.7870
# Accuracy of dog :  0.6990
# Accuracy of frog :  0.9920
# Accuracy of horse :  0.8000
# Accuracy of ship :  0.8370
# Accuracy of truck :  0.7550
# Epoch [29/100], Loss: 0.5597
# the epoch takes time: 54.783815145492554
# evaluate test set:
# Accuracy of the model on the test images: 0.8455
# Accuracy of plane :  0.6780
# Accuracy of car :  0.9600
# Accuracy of bird :  0.7880
# Accuracy of cat :  0.8340
# Accuracy of deer :  0.8850
# Accuracy of dog :  0.7580
# Accuracy of frog :  0.8910
# Accuracy of horse :  0.8580
# Accuracy of ship :  0.9450
# Accuracy of truck :  0.8580
# Epoch [30/100], Loss: 0.1769
# the epoch takes time: 55.82861566543579
# evaluate test set:
# Accuracy of the model on the test images: 0.7526
# Accuracy of plane :  0.6230
# Accuracy of car :  0.9140
# Accuracy of bird :  0.6890
# Accuracy of cat :  0.8190
# Accuracy of deer :  0.7290
# Accuracy of dog :  0.8100
# Accuracy of frog :  0.8930
# Accuracy of horse :  0.5690
# Accuracy of ship :  0.7470
# Accuracy of truck :  0.7330
# reset learning rate to: 0.01
# 0.01
# Epoch [31/100], Loss: 0.3380
# the epoch takes time: 56.45339298248291
# evaluate test set:
# Accuracy of the model on the test images: 0.9137
# Accuracy of plane :  0.9180
# Accuracy of car :  0.9720
# Accuracy of bird :  0.8800
# Accuracy of cat :  0.8090
# Accuracy of deer :  0.9370
# Accuracy of dog :  0.8830
# Accuracy of frog :  0.9350
# Accuracy of horse :  0.9180
# Accuracy of ship :  0.9410
# Accuracy of truck :  0.9440
# current best acc, tensor(0.9137, device='cuda:0')
# Epoch [32/100], Loss: 0.0093
# the epoch takes time: 56.20804142951965
# evaluate test set:
# Accuracy of the model on the test images: 0.9193
# Accuracy of plane :  0.9280
# Accuracy of car :  0.9770
# Accuracy of bird :  0.8830
# Accuracy of cat :  0.8430
# Accuracy of deer :  0.9200
# Accuracy of dog :  0.8700
# Accuracy of frog :  0.9410
# Accuracy of horse :  0.9310
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9410
# current best acc, tensor(0.9193, device='cuda:0')
# Epoch [33/100], Loss: 0.2742
# the epoch takes time: 53.7362642288208
# evaluate test set:
# Accuracy of the model on the test images: 0.9167
# Accuracy of plane :  0.9420
# Accuracy of car :  0.9670
# Accuracy of bird :  0.8900
# Accuracy of cat :  0.7970
# Accuracy of deer :  0.9160
# Accuracy of dog :  0.8760
# Accuracy of frog :  0.9450
# Accuracy of horse :  0.9250
# Accuracy of ship :  0.9480
# Accuracy of truck :  0.9610
# Epoch [34/100], Loss: 0.0525
# the epoch takes time: 56.472965717315674
# evaluate test set:
# Accuracy of the model on the test images: 0.919
# Accuracy of plane :  0.9210
# Accuracy of car :  0.9690
# Accuracy of bird :  0.8960
# Accuracy of cat :  0.8280
# Accuracy of deer :  0.9250
# Accuracy of dog :  0.8690
# Accuracy of frog :  0.9500
# Accuracy of horse :  0.9250
# Accuracy of ship :  0.9650
# Accuracy of truck :  0.9420
# Epoch [35/100], Loss: 0.0344
# the epoch takes time: 56.338879346847534
# evaluate test set:
# Accuracy of the model on the test images: 0.917
# Accuracy of plane :  0.9380
# Accuracy of car :  0.9630
# Accuracy of bird :  0.8900
# Accuracy of cat :  0.8110
# Accuracy of deer :  0.9080
# Accuracy of dog :  0.8600
# Accuracy of frog :  0.9530
# Accuracy of horse :  0.9490
# Accuracy of ship :  0.9530
# Accuracy of truck :  0.9450
# Epoch [36/100], Loss: 0.0116
# the epoch takes time: 56.3294563293457
# evaluate test set:
# Accuracy of the model on the test images: 0.9194
# Accuracy of plane :  0.9300
# Accuracy of car :  0.9670
# Accuracy of bird :  0.8980
# Accuracy of cat :  0.8290
# Accuracy of deer :  0.9390
# Accuracy of dog :  0.8380
# Accuracy of frog :  0.9510
# Accuracy of horse :  0.9330
# Accuracy of ship :  0.9540
# Accuracy of truck :  0.9550
# current best acc, tensor(0.9194, device='cuda:0')
# Epoch [37/100], Loss: 0.1234
# the epoch takes time: 55.92707324028015
# evaluate test set:
# Accuracy of the model on the test images: 0.9173
# Accuracy of plane :  0.9370
# Accuracy of car :  0.9630
# Accuracy of bird :  0.8750
# Accuracy of cat :  0.8120
# Accuracy of deer :  0.9270
# Accuracy of dog :  0.8810
# Accuracy of frog :  0.9500
# Accuracy of horse :  0.9210
# Accuracy of ship :  0.9530
# Accuracy of truck :  0.9540
# Epoch [38/100], Loss: 0.0787
# the epoch takes time: 55.80225491523743
# evaluate test set:
# Accuracy of the model on the test images: 0.9202
# Accuracy of plane :  0.9340
# Accuracy of car :  0.9640
# Accuracy of bird :  0.8870
# Accuracy of cat :  0.8200
# Accuracy of deer :  0.9300
# Accuracy of dog :  0.8900
# Accuracy of frog :  0.9410
# Accuracy of horse :  0.9190
# Accuracy of ship :  0.9600
# Accuracy of truck :  0.9570
# current best acc, tensor(0.9202, device='cuda:0')
# Epoch [39/100], Loss: 0.2993
# the epoch takes time: 55.74671483039856
# evaluate test set:
# Accuracy of the model on the test images: 0.9208
# Accuracy of plane :  0.9210
# Accuracy of car :  0.9610
# Accuracy of bird :  0.9020
# Accuracy of cat :  0.8290
# Accuracy of deer :  0.9250
# Accuracy of dog :  0.8650
# Accuracy of frog :  0.9530
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9560
# Accuracy of truck :  0.9600
# current best acc, tensor(0.9208, device='cuda:0')
# Epoch [40/100], Loss: 0.1817
# the epoch takes time: 56.267821073532104
# evaluate test set:
# Accuracy of the model on the test images: 0.9172
# Accuracy of plane :  0.9360
# Accuracy of car :  0.9630
# Accuracy of bird :  0.9040
# Accuracy of cat :  0.8580
# Accuracy of deer :  0.9030
# Accuracy of dog :  0.8190
# Accuracy of frog :  0.9330
# Accuracy of horse :  0.9410
# Accuracy of ship :  0.9570
# Accuracy of truck :  0.9580
# Epoch [41/100], Loss: 0.0439
# the epoch takes time: 55.93178629875183
# evaluate test set:
# Accuracy of the model on the test images: 0.9189
# Accuracy of plane :  0.9220
# Accuracy of car :  0.9650
# Accuracy of bird :  0.9060
# Accuracy of cat :  0.8800
# Accuracy of deer :  0.9100
# Accuracy of dog :  0.8140
# Accuracy of frog :  0.9310
# Accuracy of horse :  0.9430
# Accuracy of ship :  0.9570
# Accuracy of truck :  0.9610
# Epoch [42/100], Loss: 0.0040
# the epoch takes time: 55.88410305976868
# evaluate test set:
# Accuracy of the model on the test images: 0.9209
# Accuracy of plane :  0.9210
# Accuracy of car :  0.9680
# Accuracy of bird :  0.8950
# Accuracy of cat :  0.8430
# Accuracy of deer :  0.9360
# Accuracy of dog :  0.8540
# Accuracy of frog :  0.9590
# Accuracy of horse :  0.9300
# Accuracy of ship :  0.9580
# Accuracy of truck :  0.9450
# current best acc, tensor(0.9209, device='cuda:0')
# Epoch [43/100], Loss: 0.0013
# the epoch takes time: 56.416321992874146
# evaluate test set:
# Accuracy of the model on the test images: 0.9158
# Accuracy of plane :  0.9220
# Accuracy of car :  0.9650
# Accuracy of bird :  0.8930
# Accuracy of cat :  0.8490
# Accuracy of deer :  0.9110
# Accuracy of dog :  0.8420
# Accuracy of frog :  0.9440
# Accuracy of horse :  0.9310
# Accuracy of ship :  0.9630
# Accuracy of truck :  0.9380
# Epoch [44/100], Loss: 0.2228
# the epoch takes time: 55.776442527770996
# evaluate test set:
# Accuracy of the model on the test images: 0.9164
# Accuracy of plane :  0.9210
# Accuracy of car :  0.9670
# Accuracy of bird :  0.8980
# Accuracy of cat :  0.8060
# Accuracy of deer :  0.9130
# Accuracy of dog :  0.8680
# Accuracy of frog :  0.9530
# Accuracy of horse :  0.9270
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9520
# Epoch [45/100], Loss: 0.2494
# the epoch takes time: 56.500908851623535
# evaluate test set:
# Accuracy of the model on the test images: 0.9206
# Accuracy of plane :  0.9310
# Accuracy of car :  0.9660
# Accuracy of bird :  0.8850
# Accuracy of cat :  0.8230
# Accuracy of deer :  0.9090
# Accuracy of dog :  0.8910
# Accuracy of frog :  0.9430
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9610
# Accuracy of truck :  0.9610
# Epoch [46/100], Loss: 0.0276
# the epoch takes time: 56.12592124938965
# evaluate test set:
# Accuracy of the model on the test images: 0.917
# Accuracy of plane :  0.9030
# Accuracy of car :  0.9710
# Accuracy of bird :  0.9030
# Accuracy of cat :  0.8240
# Accuracy of deer :  0.9260
# Accuracy of dog :  0.8600
# Accuracy of frog :  0.9450
# Accuracy of horse :  0.9290
# Accuracy of ship :  0.9670
# Accuracy of truck :  0.9420
# Epoch [47/100], Loss: 0.6620
# the epoch takes time: 56.434329986572266
# evaluate test set:
# Accuracy of the model on the test images: 0.923
# Accuracy of plane :  0.9430
# Accuracy of car :  0.9620
# Accuracy of bird :  0.8960
# Accuracy of cat :  0.8190
# Accuracy of deer :  0.9210
# Accuracy of dog :  0.8860
# Accuracy of frog :  0.9520
# Accuracy of horse :  0.9370
# Accuracy of ship :  0.9610
# Accuracy of truck :  0.9530
# current best acc, tensor(0.9230, device='cuda:0')
# Epoch [48/100], Loss: 0.0489
# the epoch takes time: 56.00827503204346
# evaluate test set:
# Accuracy of the model on the test images: 0.9185
# Accuracy of plane :  0.9430
# Accuracy of car :  0.9560
# Accuracy of bird :  0.8870
# Accuracy of cat :  0.7990
# Accuracy of deer :  0.9240
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9450
# Accuracy of horse :  0.9400
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9590
# Epoch [49/100], Loss: 0.0069
# the epoch takes time: 56.18733048439026
# evaluate test set:
# Accuracy of the model on the test images: 0.9185
# Accuracy of plane :  0.9370
# Accuracy of car :  0.9580
# Accuracy of bird :  0.8720
# Accuracy of cat :  0.8340
# Accuracy of deer :  0.9220
# Accuracy of dog :  0.8640
# Accuracy of frog :  0.9510
# Accuracy of horse :  0.9250
# Accuracy of ship :  0.9560
# Accuracy of truck :  0.9660
# Epoch [50/100], Loss: 0.0155
# the epoch takes time: 55.73032188415527
# evaluate test set:
# Accuracy of the model on the test images: 0.9167
# Accuracy of plane :  0.9200
# Accuracy of car :  0.9620
# Accuracy of bird :  0.8740
# Accuracy of cat :  0.8570
# Accuracy of deer :  0.9140
# Accuracy of dog :  0.8300
# Accuracy of frog :  0.9620
# Accuracy of horse :  0.9270
# Accuracy of ship :  0.9570
# Accuracy of truck :  0.9640
# Epoch [51/100], Loss: 0.0388
# the epoch takes time: 55.49355220794678
# evaluate test set:
# Accuracy of the model on the test images: 0.9138
# Accuracy of plane :  0.9210
# Accuracy of car :  0.9710
# Accuracy of bird :  0.8700
# Accuracy of cat :  0.7940
# Accuracy of deer :  0.9100
# Accuracy of dog :  0.9050
# Accuracy of frog :  0.9480
# Accuracy of horse :  0.9170
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9430
# Epoch [52/100], Loss: 0.0232
# the epoch takes time: 56.05097317695618
# evaluate test set:
# Accuracy of the model on the test images: 0.9205
# Accuracy of plane :  0.9290
# Accuracy of car :  0.9700
# Accuracy of bird :  0.8790
# Accuracy of cat :  0.8550
# Accuracy of deer :  0.9160
# Accuracy of dog :  0.8460
# Accuracy of frog :  0.9610
# Accuracy of horse :  0.9470
# Accuracy of ship :  0.9490
# Accuracy of truck :  0.9530
# Epoch [53/100], Loss: 0.1849
# the epoch takes time: 56.332253217697144
# evaluate test set:
# Accuracy of the model on the test images: 0.9184
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9530
# Accuracy of bird :  0.8890
# Accuracy of cat :  0.8220
# Accuracy of deer :  0.9130
# Accuracy of dog :  0.8760
# Accuracy of frog :  0.9370
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9540
# Accuracy of truck :  0.9590
# Epoch [54/100], Loss: 0.0727
# the epoch takes time: 55.804900884628296
# evaluate test set:
# Accuracy of the model on the test images: 0.9166
# Accuracy of plane :  0.8990
# Accuracy of car :  0.9660
# Accuracy of bird :  0.8890
# Accuracy of cat :  0.8230
# Accuracy of deer :  0.9410
# Accuracy of dog :  0.8820
# Accuracy of frog :  0.9360
# Accuracy of horse :  0.9170
# Accuracy of ship :  0.9490
# Accuracy of truck :  0.9640
# Epoch [55/100], Loss: 0.0173
# the epoch takes time: 55.823782205581665
# evaluate test set:
# Accuracy of the model on the test images: 0.9187
# Accuracy of plane :  0.9510
# Accuracy of car :  0.9690
# Accuracy of bird :  0.8860
# Accuracy of cat :  0.7980
# Accuracy of deer :  0.9390
# Accuracy of dog :  0.8820
# Accuracy of frog :  0.9210
# Accuracy of horse :  0.9410
# Accuracy of ship :  0.9510
# Accuracy of truck :  0.9490
# Epoch [56/100], Loss: 0.0906
# the epoch takes time: 55.98406267166138
# evaluate test set:
# Accuracy of the model on the test images: 0.9156
# Accuracy of plane :  0.9120
# Accuracy of car :  0.9740
# Accuracy of bird :  0.8960
# Accuracy of cat :  0.7980
# Accuracy of deer :  0.9370
# Accuracy of dog :  0.8480
# Accuracy of frog :  0.9480
# Accuracy of horse :  0.9330
# Accuracy of ship :  0.9620
# Accuracy of truck :  0.9480
# Epoch [57/100], Loss: 0.0439
# the epoch takes time: 56.30971932411194
# evaluate test set:
# Accuracy of the model on the test images: 0.9236
# Accuracy of plane :  0.9350
# Accuracy of car :  0.9680
# Accuracy of bird :  0.8990
# Accuracy of cat :  0.8410
# Accuracy of deer :  0.9330
# Accuracy of dog :  0.8950
# Accuracy of frog :  0.9460
# Accuracy of horse :  0.9110
# Accuracy of ship :  0.9530
# Accuracy of truck :  0.9550
# current best acc, tensor(0.9236, device='cuda:0')
# Epoch [58/100], Loss: 0.0021
# the epoch takes time: 56.00143384933472
# evaluate test set:
# Accuracy of the model on the test images: 0.9095
# Accuracy of plane :  0.9300
# Accuracy of car :  0.9720
# Accuracy of bird :  0.8810
# Accuracy of cat :  0.8900
# Accuracy of deer :  0.8910
# Accuracy of dog :  0.7810
# Accuracy of frog :  0.9390
# Accuracy of horse :  0.9250
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9270
# Epoch [59/100], Loss: 0.0127
# the epoch takes time: 56.309865951538086
# evaluate test set:
# Accuracy of the model on the test images: 0.9194
# Accuracy of plane :  0.9260
# Accuracy of car :  0.9610
# Accuracy of bird :  0.8850
# Accuracy of cat :  0.8820
# Accuracy of deer :  0.9130
# Accuracy of dog :  0.8220
# Accuracy of frog :  0.9480
# Accuracy of horse :  0.9510
# Accuracy of ship :  0.9510
# Accuracy of truck :  0.9550
# Epoch [60/100], Loss: 0.0595
# the epoch takes time: 55.8748984336853
# evaluate test set:
# Accuracy of the model on the test images: 0.9193
# Accuracy of plane :  0.9410
# Accuracy of car :  0.9580
# Accuracy of bird :  0.8690
# Accuracy of cat :  0.8430
# Accuracy of deer :  0.9140
# Accuracy of dog :  0.8880
# Accuracy of frog :  0.9490
# Accuracy of horse :  0.9120
# Accuracy of ship :  0.9600
# Accuracy of truck :  0.9590
# reset learning rate to: 0.001
# 0.001
# Epoch [61/100], Loss: 0.1033
# the epoch takes time: 55.70617628097534
# evaluate test set:
# Accuracy of the model on the test images: 0.9249
# Accuracy of plane :  0.9380
# Accuracy of car :  0.9630
# Accuracy of bird :  0.8890
# Accuracy of cat :  0.8470
# Accuracy of deer :  0.9350
# Accuracy of dog :  0.8690
# Accuracy of frog :  0.9510
# Accuracy of horse :  0.9370
# Accuracy of ship :  0.9640
# Accuracy of truck :  0.9560
# current best acc, tensor(0.9249, device='cuda:0')
# Epoch [62/100], Loss: 0.0305
# the epoch takes time: 56.83834409713745
# evaluate test set:
# Accuracy of the model on the test images: 0.925
# Accuracy of plane :  0.9440
# Accuracy of car :  0.9670
# Accuracy of bird :  0.8990
# Accuracy of cat :  0.8280
# Accuracy of deer :  0.9340
# Accuracy of dog :  0.8760
# Accuracy of frog :  0.9520
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9630
# Accuracy of truck :  0.9510
# current best acc, tensor(0.9250, device='cuda:0')
# Epoch [63/100], Loss: 0.0464
# the epoch takes time: 55.97212338447571
# evaluate test set:
# Accuracy of the model on the test images: 0.9256
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9680
# Accuracy of bird :  0.8900
# Accuracy of cat :  0.8470
# Accuracy of deer :  0.9310
# Accuracy of dog :  0.8820
# Accuracy of frog :  0.9490
# Accuracy of horse :  0.9370
# Accuracy of ship :  0.9540
# Accuracy of truck :  0.9530
# current best acc, tensor(0.9256, device='cuda:0')
# Epoch [64/100], Loss: 0.0017
# the epoch takes time: 56.29663348197937
# evaluate test set:
# Accuracy of the model on the test images: 0.9258
# Accuracy of plane :  0.9300
# Accuracy of car :  0.9700
# Accuracy of bird :  0.8980
# Accuracy of cat :  0.8600
# Accuracy of deer :  0.9300
# Accuracy of dog :  0.8630
# Accuracy of frog :  0.9500
# Accuracy of horse :  0.9410
# Accuracy of ship :  0.9610
# Accuracy of truck :  0.9550
# current best acc, tensor(0.9258, device='cuda:0')
# Epoch [65/100], Loss: 0.0125
# the epoch takes time: 55.99359130859375
# evaluate test set:
# Accuracy of the model on the test images: 0.9249
# Accuracy of plane :  0.9310
# Accuracy of car :  0.9640
# Accuracy of bird :  0.9040
# Accuracy of cat :  0.8240
# Accuracy of deer :  0.9380
# Accuracy of dog :  0.8790
# Accuracy of frog :  0.9530
# Accuracy of horse :  0.9400
# Accuracy of ship :  0.9550
# Accuracy of truck :  0.9610
# Epoch [66/100], Loss: 0.0051
# the epoch takes time: 55.88318610191345
# evaluate test set:
# Accuracy of the model on the test images: 0.9276
# Accuracy of plane :  0.9470
# Accuracy of car :  0.9730
# Accuracy of bird :  0.8940
# Accuracy of cat :  0.8370
# Accuracy of deer :  0.9460
# Accuracy of dog :  0.8750
# Accuracy of frog :  0.9540
# Accuracy of horse :  0.9380
# Accuracy of ship :  0.9580
# Accuracy of truck :  0.9540
# current best acc, tensor(0.9276, device='cuda:0')
# Epoch [67/100], Loss: 0.0013
# the epoch takes time: 56.176917552948
# evaluate test set:
# Accuracy of the model on the test images: 0.9263
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9780
# Accuracy of bird :  0.8960
# Accuracy of cat :  0.8340
# Accuracy of deer :  0.9450
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9440
# Accuracy of horse :  0.9410
# Accuracy of ship :  0.9560
# Accuracy of truck :  0.9510
# Epoch [68/100], Loss: 0.0483
# the epoch takes time: 56.363749504089355
# evaluate test set:
# Accuracy of the model on the test images: 0.9261
# Accuracy of plane :  0.9490
# Accuracy of car :  0.9640
# Accuracy of bird :  0.8940
# Accuracy of cat :  0.8310
# Accuracy of deer :  0.9420
# Accuracy of dog :  0.8860
# Accuracy of frog :  0.9520
# Accuracy of horse :  0.9280
# Accuracy of ship :  0.9650
# Accuracy of truck :  0.9500
# Epoch [69/100], Loss: 0.0150
# the epoch takes time: 55.449190616607666
# evaluate test set:
# Accuracy of the model on the test images: 0.9264
# Accuracy of plane :  0.9540
# Accuracy of car :  0.9620
# Accuracy of bird :  0.8890
# Accuracy of cat :  0.8370
# Accuracy of deer :  0.9360
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9450
# Accuracy of horse :  0.9430
# Accuracy of ship :  0.9630
# Accuracy of truck :  0.9620
# Epoch [70/100], Loss: 0.0008
# the epoch takes time: 55.765034914016724
# evaluate test set:
# Accuracy of the model on the test images: 0.9276
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9670
# Accuracy of bird :  0.8890
# Accuracy of cat :  0.8260
# Accuracy of deer :  0.9440
# Accuracy of dog :  0.8870
# Accuracy of frog :  0.9590
# Accuracy of horse :  0.9390
# Accuracy of ship :  0.9600
# Accuracy of truck :  0.9600
# Epoch [71/100], Loss: 0.0020
# the epoch takes time: 55.45540523529053
# evaluate test set:
# Accuracy of the model on the test images: 0.9259
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9560
# Accuracy of bird :  0.8840
# Accuracy of cat :  0.8450
# Accuracy of deer :  0.9490
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9480
# Accuracy of horse :  0.9380
# Accuracy of ship :  0.9620
# Accuracy of truck :  0.9590
# Epoch [72/100], Loss: 0.0575
# the epoch takes time: 55.49443221092224
# evaluate test set:
# Accuracy of the model on the test images: 0.9282
# Accuracy of plane :  0.9410
# Accuracy of car :  0.9700
# Accuracy of bird :  0.8950
# Accuracy of cat :  0.8520
# Accuracy of deer :  0.9430
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9560
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9570
# Accuracy of truck :  0.9590
# current best acc, tensor(0.9282, device='cuda:0')
# Epoch [73/100], Loss: 0.0116
# the epoch takes time: 55.50818872451782
# evaluate test set:
# Accuracy of the model on the test images: 0.9272
# Accuracy of plane :  0.9590
# Accuracy of car :  0.9680
# Accuracy of bird :  0.8810
# Accuracy of cat :  0.8390
# Accuracy of deer :  0.9420
# Accuracy of dog :  0.8800
# Accuracy of frog :  0.9580
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9530
# Accuracy of truck :  0.9560
# Epoch [74/100], Loss: 0.0076
# the epoch takes time: 55.976048707962036
# evaluate test set:
# Accuracy of the model on the test images: 0.9259
# Accuracy of plane :  0.9460
# Accuracy of car :  0.9600
# Accuracy of bird :  0.8850
# Accuracy of cat :  0.8540
# Accuracy of deer :  0.9210
# Accuracy of dog :  0.8830
# Accuracy of frog :  0.9590
# Accuracy of horse :  0.9340
# Accuracy of ship :  0.9570
# Accuracy of truck :  0.9600
# Epoch [75/100], Loss: 0.3065
# the epoch takes time: 55.87369704246521
# evaluate test set:
# Accuracy of the model on the test images: 0.9258
# Accuracy of plane :  0.9590
# Accuracy of car :  0.9640
# Accuracy of bird :  0.8970
# Accuracy of cat :  0.8350
# Accuracy of deer :  0.9200
# Accuracy of dog :  0.8700
# Accuracy of frog :  0.9540
# Accuracy of horse :  0.9390
# Accuracy of ship :  0.9610
# Accuracy of truck :  0.9590
# Epoch [76/100], Loss: 0.0819
# the epoch takes time: 56.29990887641907
# evaluate test set:
# Accuracy of the model on the test images: 0.9274
# Accuracy of plane :  0.9480
# Accuracy of car :  0.9760
# Accuracy of bird :  0.9010
# Accuracy of cat :  0.8430
# Accuracy of deer :  0.9260
# Accuracy of dog :  0.8810
# Accuracy of frog :  0.9490
# Accuracy of horse :  0.9400
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9510
# Epoch [77/100], Loss: 0.0344
# the epoch takes time: 56.15933799743652
# evaluate test set:
# Accuracy of the model on the test images: 0.9272
# Accuracy of plane :  0.9420
# Accuracy of car :  0.9740
# Accuracy of bird :  0.9000
# Accuracy of cat :  0.8450
# Accuracy of deer :  0.9250
# Accuracy of dog :  0.8750
# Accuracy of frog :  0.9500
# Accuracy of horse :  0.9460
# Accuracy of ship :  0.9600
# Accuracy of truck :  0.9550
# Epoch [78/100], Loss: 0.0958
# the epoch takes time: 56.119927644729614
# evaluate test set:
# Accuracy of the model on the test images: 0.9275
# Accuracy of plane :  0.9430
# Accuracy of car :  0.9640
# Accuracy of bird :  0.8970
# Accuracy of cat :  0.8470
# Accuracy of deer :  0.9450
# Accuracy of dog :  0.8670
# Accuracy of frog :  0.9480
# Accuracy of horse :  0.9480
# Accuracy of ship :  0.9570
# Accuracy of truck :  0.9590
# Epoch [79/100], Loss: 0.0015
# the epoch takes time: 55.95849108695984
# evaluate test set:
# Accuracy of the model on the test images: 0.9284
# Accuracy of plane :  0.9480
# Accuracy of car :  0.9720
# Accuracy of bird :  0.8880
# Accuracy of cat :  0.8570
# Accuracy of deer :  0.9350
# Accuracy of dog :  0.8770
# Accuracy of frog :  0.9560
# Accuracy of horse :  0.9410
# Accuracy of ship :  0.9580
# Accuracy of truck :  0.9520
# current best acc, tensor(0.9284, device='cuda:0')
# Epoch [80/100], Loss: 0.0136
# the epoch takes time: 56.117448806762695
# evaluate test set:
# Accuracy of the model on the test images: 0.9263
# Accuracy of plane :  0.9490
# Accuracy of car :  0.9630
# Accuracy of bird :  0.8900
# Accuracy of cat :  0.8140
# Accuracy of deer :  0.9410
# Accuracy of dog :  0.8850
# Accuracy of frog :  0.9500
# Accuracy of horse :  0.9520
# Accuracy of ship :  0.9610
# Accuracy of truck :  0.9580
# Epoch [81/100], Loss: 0.0003
# the epoch takes time: 55.81778001785278
# evaluate test set:
# Accuracy of the model on the test images: 0.9259
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9590
# Accuracy of bird :  0.8960
# Accuracy of cat :  0.8450
# Accuracy of deer :  0.9310
# Accuracy of dog :  0.8670
# Accuracy of frog :  0.9460
# Accuracy of horse :  0.9480
# Accuracy of ship :  0.9600
# Accuracy of truck :  0.9620
# Epoch [82/100], Loss: 0.5326
# the epoch takes time: 56.1419620513916
# evaluate test set:
# Accuracy of the model on the test images: 0.9269
# Accuracy of plane :  0.9370
# Accuracy of car :  0.9690
# Accuracy of bird :  0.8930
# Accuracy of cat :  0.8490
# Accuracy of deer :  0.9410
# Accuracy of dog :  0.8670
# Accuracy of frog :  0.9540
# Accuracy of horse :  0.9430
# Accuracy of ship :  0.9580
# Accuracy of truck :  0.9580
# Epoch [83/100], Loss: 0.1842
# the epoch takes time: 55.83122110366821
# evaluate test set:
# Accuracy of the model on the test images: 0.925
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9720
# Accuracy of bird :  0.8950
# Accuracy of cat :  0.8190
# Accuracy of deer :  0.9410
# Accuracy of dog :  0.8710
# Accuracy of frog :  0.9460
# Accuracy of horse :  0.9440
# Accuracy of ship :  0.9610
# Accuracy of truck :  0.9560
# Epoch [84/100], Loss: 0.1085
# the epoch takes time: 55.90538477897644
# evaluate test set:
# Accuracy of the model on the test images: 0.9265
# Accuracy of plane :  0.9290
# Accuracy of car :  0.9650
# Accuracy of bird :  0.8970
# Accuracy of cat :  0.8470
# Accuracy of deer :  0.9310
# Accuracy of dog :  0.8720
# Accuracy of frog :  0.9590
# Accuracy of horse :  0.9420
# Accuracy of ship :  0.9610
# Accuracy of truck :  0.9620
# Epoch [85/100], Loss: 0.0122
# the epoch takes time: 56.242894411087036
# evaluate test set:
# Accuracy of the model on the test images: 0.9281
# Accuracy of plane :  0.9460
# Accuracy of car :  0.9720
# Accuracy of bird :  0.9010
# Accuracy of cat :  0.8570
# Accuracy of deer :  0.9310
# Accuracy of dog :  0.8720
# Accuracy of frog :  0.9530
# Accuracy of horse :  0.9320
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9580
# Epoch [86/100], Loss: 0.1502
# the epoch takes time: 56.3643901348114
# evaluate test set:
# Accuracy of the model on the test images: 0.926
# Accuracy of plane :  0.9340
# Accuracy of car :  0.9640
# Accuracy of bird :  0.8960
# Accuracy of cat :  0.8480
# Accuracy of deer :  0.9380
# Accuracy of dog :  0.8630
# Accuracy of frog :  0.9400
# Accuracy of horse :  0.9510
# Accuracy of ship :  0.9620
# Accuracy of truck :  0.9640
# Epoch [87/100], Loss: 0.0256
# the epoch takes time: 56.2347846031189
# evaluate test set:
# Accuracy of the model on the test images: 0.9277
# Accuracy of plane :  0.9520
# Accuracy of car :  0.9670
# Accuracy of bird :  0.9030
# Accuracy of cat :  0.8340
# Accuracy of deer :  0.9390
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9520
# Accuracy of horse :  0.9430
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9550
# Epoch [88/100], Loss: 0.0211
# the epoch takes time: 55.6557776927948
# evaluate test set:
# Accuracy of the model on the test images: 0.9264
# Accuracy of plane :  0.9430
# Accuracy of car :  0.9680
# Accuracy of bird :  0.9060
# Accuracy of cat :  0.8430
# Accuracy of deer :  0.9260
# Accuracy of dog :  0.8690
# Accuracy of frog :  0.9450
# Accuracy of horse :  0.9420
# Accuracy of ship :  0.9630
# Accuracy of truck :  0.9590
# Epoch [89/100], Loss: 0.0307
# the epoch takes time: 55.412062644958496
# evaluate test set:
# Accuracy of the model on the test images: 0.9277
# Accuracy of plane :  0.9470
# Accuracy of car :  0.9590
# Accuracy of bird :  0.9000
# Accuracy of cat :  0.8410
# Accuracy of deer :  0.9500
# Accuracy of dog :  0.8620
# Accuracy of frog :  0.9470
# Accuracy of horse :  0.9470
# Accuracy of ship :  0.9630
# Accuracy of truck :  0.9610
# Epoch [90/100], Loss: 0.0159
# the epoch takes time: 54.671355962753296
# evaluate test set:
# Accuracy of the model on the test images: 0.9269
# Accuracy of plane :  0.9400
# Accuracy of car :  0.9700
# Accuracy of bird :  0.8850
# Accuracy of cat :  0.8590
# Accuracy of deer :  0.9350
# Accuracy of dog :  0.8750
# Accuracy of frog :  0.9480
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9620
# Accuracy of truck :  0.9590
# reset learning rate to: 0.0001
# 0.0001
# Epoch [91/100], Loss: 0.0281
# the epoch takes time: 55.407103061676025
# evaluate test set:
# Accuracy of the model on the test images: 0.9272
# Accuracy of plane :  0.9390
# Accuracy of car :  0.9700
# Accuracy of bird :  0.8930
# Accuracy of cat :  0.8390
# Accuracy of deer :  0.9450
# Accuracy of dog :  0.8760
# Accuracy of frog :  0.9550
# Accuracy of horse :  0.9360
# Accuracy of ship :  0.9620
# Accuracy of truck :  0.9570
# Epoch [92/100], Loss: 0.0168
# the epoch takes time: 55.786463260650635
# evaluate test set:
# Accuracy of the model on the test images: 0.9273
# Accuracy of plane :  0.9570
# Accuracy of car :  0.9650
# Accuracy of bird :  0.9010
# Accuracy of cat :  0.8470
# Accuracy of deer :  0.9400
# Accuracy of dog :  0.8660
# Accuracy of frog :  0.9460
# Accuracy of horse :  0.9390
# Accuracy of ship :  0.9530
# Accuracy of truck :  0.9590
# Epoch [93/100], Loss: 0.0173
# the epoch takes time: 54.94957160949707
# evaluate test set:
# Accuracy of the model on the test images: 0.9255
# Accuracy of plane :  0.9470
# Accuracy of car :  0.9690
# Accuracy of bird :  0.8960
# Accuracy of cat :  0.8120
# Accuracy of deer :  0.9340
# Accuracy of dog :  0.8830
# Accuracy of frog :  0.9470
# Accuracy of horse :  0.9450
# Accuracy of ship :  0.9600
# Accuracy of truck :  0.9620
# Epoch [94/100], Loss: 0.1032
# the epoch takes time: 55.07844066619873
# evaluate test set:
# Accuracy of the model on the test images: 0.927
# Accuracy of plane :  0.9340
# Accuracy of car :  0.9680
# Accuracy of bird :  0.8970
# Accuracy of cat :  0.8460
# Accuracy of deer :  0.9290
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9570
# Accuracy of horse :  0.9460
# Accuracy of ship :  0.9620
# Accuracy of truck :  0.9580
# Epoch [95/100], Loss: 0.0077
# the epoch takes time: 55.15709900856018
# evaluate test set:
# Accuracy of the model on the test images: 0.9278
# Accuracy of plane :  0.9400
# Accuracy of car :  0.9680
# Accuracy of bird :  0.9040
# Accuracy of cat :  0.8320
# Accuracy of deer :  0.9430
# Accuracy of dog :  0.8850
# Accuracy of frog :  0.9470
# Accuracy of horse :  0.9400
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9600
# Epoch [96/100], Loss: 0.0848
# the epoch takes time: 55.310609102249146
# evaluate test set:
# Accuracy of the model on the test images: 0.9282
# Accuracy of plane :  0.9490
# Accuracy of car :  0.9690
# Accuracy of bird :  0.8890
# Accuracy of cat :  0.8440
# Accuracy of deer :  0.9380
# Accuracy of dog :  0.8880
# Accuracy of frog :  0.9570
# Accuracy of horse :  0.9330
# Accuracy of ship :  0.9560
# Accuracy of truck :  0.9590
# Epoch [97/100], Loss: 0.0835
# the epoch takes time: 54.92670702934265
# evaluate test set:
# Accuracy of the model on the test images: 0.9277
# Accuracy of plane :  0.9400
# Accuracy of car :  0.9640
# Accuracy of bird :  0.9000
# Accuracy of cat :  0.8380
# Accuracy of deer :  0.9410
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9510
# Accuracy of horse :  0.9510
# Accuracy of ship :  0.9590
# Accuracy of truck :  0.9600
# Epoch [98/100], Loss: 0.0549
# the epoch takes time: 55.6090943813324
# evaluate test set:
# Accuracy of the model on the test images: 0.9275
# Accuracy of plane :  0.9500
# Accuracy of car :  0.9630
# Accuracy of bird :  0.9070
# Accuracy of cat :  0.8280
# Accuracy of deer :  0.9370
# Accuracy of dog :  0.8820
# Accuracy of frog :  0.9530
# Accuracy of horse :  0.9320
# Accuracy of ship :  0.9630
# Accuracy of truck :  0.9600
# Epoch [99/100], Loss: 0.1401
# the epoch takes time: 56.121520042419434
# evaluate test set:
# Accuracy of the model on the test images: 0.9278
# Accuracy of plane :  0.9510
# Accuracy of car :  0.9670
# Accuracy of bird :  0.9050
# Accuracy of cat :  0.8480
# Accuracy of deer :  0.9420
# Accuracy of dog :  0.8760
# Accuracy of frog :  0.9500
# Accuracy of horse :  0.9250
# Accuracy of ship :  0.9550
# Accuracy of truck :  0.9590
# Epoch [100/100], Loss: 0.0025
# the epoch takes time: 59.10904312133789
# evaluate test set:
# Accuracy of the model on the test images: 0.9277
# Accuracy of plane :  0.9450
# Accuracy of car :  0.9680
# Accuracy of bird :  0.8810
# Accuracy of cat :  0.8540
# Accuracy of deer :  0.9440
# Accuracy of dog :  0.8730
# Accuracy of frog :  0.9500
# Accuracy of horse :  0.9430
# Accuracy of ship :  0.9600
# Accuracy of truck :  0.9590

# %%
import json
if is_train:
    json_str = json.dumps(vis_data)
    with open('vis_data_resnet.json', 'w', encoding='utf-8') as json_file:
        json_file.write(json_str)
